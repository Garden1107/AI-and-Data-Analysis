# %% [markdown]
# <a href="https://colab.research.google.com/github/Garden1107/AI-and-Data-Analysis/blob/main/AI3%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = ["임정원","이동구","삼동구","사동구"]
age = [21,23,52,41]

# %%
import seaborn as sns

# %%
a = sns.load_dataset('tips')       #a라는 저장공간에 데이터를 넣음   예가 핵심! 얼마나 객관적이고 중요한 자료를 넣는지.

# %%
a.info()               #정보알기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.relplot(data=a, x='total_bill', y="tip" , col="time")          #relplot 점자그래프 함수   //col열,을 타임으로 하기

# %%
import pandas as pd

# %%
pd.read_csv('1.txt')    #가져오는게 아니라 읽어주는거.
# Out:
#    name      sex   age   score
# 0  kang     male    20     100
# 1   lee   female    21      85
# 2   kim   female    35      79

# %%
a = pd.read_csv('1.txt')   #이러면 a공간에 저장된거임.

# %%
pd.read_excel('3주_data_연도별출생인구.xlsx')#엑셀파일 하고 csv만 지원 판다스,엑셀파일은 끝에 엑셀파일이라고 적어줘야함.
# Out:
#       연도    출생아수  천명당출생률
# 0   1951  728175    37.7
# 1   1952  775630    39.6
# 2   1953  830330    41.6
# 3   1954  892236    43.4
# 4   1955  961055    45.4
# ..   ...     ...     ...
# 63  2014  435435     8.6
# 64  2015  438420     8.6
# 65  2016  406243     7.9
# 66  2017  357771     7.0
# 67  2018  326900     6.4
#
# [68 rows x 3 columns]

# %%
b = pd.read_excel('3주_data_연도별출생인구.xlsx')

# %%
pd.read_csv('유기동물보호현황.csv', encoding='cp949')     #어디에서 만들어졌는지에(워드,한글~) 따라서 읽지를 못함. 속성들 encoding꼭알아둬라, 한글깨지는거. 피피티 봐보셈.
# Out:
#     자치구별(1)  자치구별(2)    시점     합계    합계.1   합계.2   합계.3  합계.4   합계.5    합계.6  \
# 0   자치구별(1)  자치구별(2)    시점      개       개      개      개     개    고양이     고양이
# 1   자치구별(1)  자치구별(2)    시점     소계  인도(주인)   입양분양  폐사안락사  계류기증     소계  인도(주인)
# 2        합계       소계  2021  2,784   1,260  1,110    341    73  2,526      72
# 3        합계       소계  2022  2,491   1,110    814    536    31  2,134      56
# 4        합계      종로구  2021     92      24     43     19     6     94       -
# 5        합계      종로구  2022     79      28     22     29     -    103       1
# 6        합계       중구  2021     32      20      5      5     2     56       -
# 7        합계       중구  2022     36      19     10      7     -     47       1
# 8        합계      용산구  2021    112      80     30      1     1    146       5
# 9        합계      용산구  2022    118      79     33      5     1    115      11
# 10       합계      성동구  2021     75      25     36     13     1     77       -
# ...

# %%
c = pd.read_csv('유기동물보호현황.csv', encoding='cp949')    #인코딩형식 주의

# %%
pd.read_csv('2.txt')#텝으로 구분되어있을경우, delimiter사용
# Out:
#   이름\t성별\tage\tscore
# 0    강동구\t남\t20\t100
# 1     이동구\t여\t21\t85
# 2     삼동구\t여\t35\t79

# %%
pd.read_csv('2.txt' , delimiter = '\t')  #딜리미터 옆에있는 따옴표안에 내가 뭐마다 띄워줄까 이야기, 따라서 \t적어줌.
# Out:
#     이름 성별  age  score
# 0  강동구  남   20    100
# 1  이동구  여   21     85
# 2  삼동구  여   35     79
